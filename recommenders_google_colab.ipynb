# %% [markdown]
# <a href="https://colab.research.google.com/github/illustrateme/machine-learning/blob/main/recommenders_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Constructing TensorFlow Recommenders Model

# %%
# !pip install -q tensorflow-recommenders
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 5.6 MB/s eta 0:00:00

# %%
import tensorflow_recommenders as tfrs

# %%
import pandas as pd
import numpy as np

# %%
import string

# %%
url = 'https://raw.githubusercontent.com/illustrateme/machine-learning/main/fiverr_data.csv'
sf  = pd.read_csv(url)
#Ilustrator CSV
sf.head()
# Out:
#   illustrator_name  gig_rating  gig_price_from  \
# 0     nadia_younus         5.0              60
# 1    mariya_logo99         4.9              15
# 2      mountdesign         4.9              10
# 3     ahmed_gfx786         4.9               5
# 4         websutra         4.9             400
#
#                                          gig_img_url  \
# 0  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 1  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 2  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 3  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 4  https://fiverr-res.cloudinary.com/t_gig_cards_...
#
#                                              gig_url gig_design_type  \
# 0  https://www.fiverr.com/nadia_younus/do-minimal...           logos
# 1  https://www.fiverr.com/mariya_logo99/do-creati...           logos
# 2  https://www.fiverr.com/mountdesign/design-3-pr...           logos
# 3  https://www.fiverr.com/ahmed_gfx786/design-a-u...           logos
# 4  https://www.fiverr.com/websutra/draw-an-unique...           logos
#
#   gig_design_style client_origins     client_names illustrator_origins
# 0       minimalist         Canada     stoxventures            Pakistan
# 1       minimalist          Italy      lifehossain          Bangladesh
# 2       minimalist  United States  stormproofrooof               India
# 3       minimalist         France         remi_bgd            Pakistan
# 4       minimalist  United States       tribolumen           Sri Lanka

# %%
fiverr_df = pd.read_csv( url , delimiter=',')

# %%
fiverr_df.head(6)
# Out:
#   illustrator_name  gig_rating  gig_price_from  \
# 0     nadia_younus         5.0              60
# 1    mariya_logo99         4.9              15
# 2      mountdesign         4.9              10
# 3     ahmed_gfx786         4.9               5
# 4         websutra         4.9             400
# 5          kiara43         4.9               5
#
#                                          gig_img_url  \
# 0  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 1  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 2  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 3  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 4  https://fiverr-res.cloudinary.com/t_gig_cards_...
# 5  https://fiverr-res.cloudinary.com/t_gig_cards_...
#
#                                              gig_url gig_design_type  \
# 0  https://www.fiverr.com/nadia_younus/do-minimal...           logos
# 1  https://www.fiverr.com/mariya_logo99/do-creati...           logos
# 2  https://www.fiverr.com/mountdesign/design-3-pr...           logos
# 3  https://www.fiverr.com/ahmed_gfx786/design-a-u...           logos
# 4  https://www.fiverr.com/websutra/draw-an-unique...           logos
# 5  https://www.fiverr.com/kiara43/create-modern-m...           logos
#
#   gig_design_style client_origins     client_names illustrator_origins
# 0       minimalist         Canada     stoxventures            Pakistan
# 1       minimalist          Italy      lifehossain          Bangladesh
# 2       minimalist  United States  stormproofrooof               India
# 3       minimalist         France         remi_bgd            Pakistan
# 4       minimalist  United States       tribolumen           Sri Lanka
# 5       minimalist        Germany  sustainifytoday           Sri Lanka

# %%
fiverr_df = fiverr_df.dropna().drop_duplicates().reset_index(drop=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
price = fiverr_df[['gig_price_from']]

# %%
scaler = MinMaxScaler()

# %%
price=scaler.fit_transform(price)

# %%
fiverr_df['gig_price_from']=price

# %%
fiverr_df['gig_rating']=np.asarray(fiverr_df['gig_rating'],dtype=np.float64) / 5

# %%
cos_sim_df = fiverr_df[['gig_img_url','gig_price_from','gig_design_type','gig_design_style', 'illustrator_origins']]

# %%
def remove_punc(text):
    cleaned = text.translate(str.maketrans('','', string.punctuation)).lower()
    return cleaned

# %%
cos_sim_df['illustrator_origins']=cos_sim_df['illustrator_origins'].apply(remove_punc)
# Out:
# <ipython-input-20-3541209e0e0f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cos_sim_df['illustrator_origins']=cos_sim_df['illustrator_origins'].apply(remove_punc)

# %%
cos_sim_df['joined_feat'] = ''
cos_sim_df['joined_feat'] = cos_sim_df[cos_sim_df.columns[2:]].apply(lambda x: ' '.join(x), axis=1)
# Out:
# <ipython-input-21-8ae95ec5835e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cos_sim_df['joined_feat'] = ''
# <ipython-input-21-8ae95ec5835e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cos_sim_df['joined_feat'] = cos_sim_df[cos_sim_df.columns[2:]].apply(lambda x: ' '.join(x), axis=1)

# %%
cos_sim_df.set_index('gig_img_url', inplace=True)

# %%
cos_sim_df=cos_sim_df[['gig_price_from', 'joined_feat']]

# %%
cos_sim_df.head()
# Out:
#                                                     gig_price_from  \
# gig_img_url
# https://fiverr-res.cloudinary.com/t_gig_cards_w...        0.018425
# https://fiverr-res.cloudinary.com/t_gig_cards_w...        0.003350
# https://fiverr-res.cloudinary.com/t_gig_cards_w...        0.001675
# https://fiverr-res.cloudinary.com/t_gig_cards_w...        0.000000
# https://fiverr-res.cloudinary.com/t_gig_cards_w...        0.132328
#
#                                                                      joined_feat
# gig_img_url
# https://fiverr-res.cloudinary.com/t_gig_cards_w...    logos minimalist pakistan
# https://fiverr-res.cloudinary.com/t_gig_cards_w...  logos minimalist bangladesh
# https://fiverr-res.cloudinary.com/t_gig_cards_w...       logos minimalist india
# https://fiverr-res.cloudinary.com/t_gig_cards_w...    logos minimalist pakistan
# https://fiverr-res.cloudinary.com/t_gig_cards_w...   logos minimalist sri lanka

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(cos_sim_df['joined_feat'])
tfidf_matrix.shape
# Out:
# (1686, 132)

# %%
helpp = tfidf_matrix.toarray()

# %%
helpp.shape
# Out:
# (1686, 132)

# %%
helppp = np.hstack((cos_sim_df[['gig_price_from']], helpp))

# %%
helppp.shape
# Out:
# (1686, 133)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cos_sim = cosine_similarity(helppp)

# %%
cos_sim.shape
# Out:
# (1686, 1686)

# %%
def predict(gig_img_url_, top_n=11):
    data = cos_sim_df.reset_index()
    final_df = pd.concat([fiverr_df['gig_rating'], data], axis=1)
    gig_index = data[data['gig_img_url'] == gig_img_url_].index
    similarity = cos_sim[gig_index[0]].T

    sim_df = pd.DataFrame(similarity, columns=['similarity'])
    final_df = pd.concat([final_df, sim_df], axis=1)
    # You can also play around with the number
    final_df['gig_rating'] = final_df['gig_rating'][gig_index[0]] * final_df['similarity']
    final_df=final_df.drop(gig_index[0])
    final_df_sorted = final_df.sort_values(by='gig_rating', ascending=False).head(top_n)
    final_df_sorted['client_names'] = fiverr_df['client_names'][gig_index[0]]
    final_df_sorted = final_df_sorted[['gig_img_url', 'client_names', 'gig_rating']]

    return final_df_sorted

# %%
for_test_df=predict(fiverr_df['gig_img_url'][100])

# %%
for_model_df=fiverr_df[['gig_img_url', 'client_names', 'gig_rating']]

ratings = ratings.map(lambda x: {
    'gig_img_url': x['gig_img_url'],
    'client_names': x['client_names'],
    'gig_rating': float(x['gig_rating'])
})

imgs = imgs.map(lambda x: x['gig_img_url'])

# %%
unique_gig_imgs = np.unique(np.concatenate(list(imgs.batch(1000))))
unique_client_names = np.unique(np.concatenate(list(ratings.batch(1000).map(lambda x: x["client_names"]))))
tf.random.set_seed(42)
shuffled = ratings.shuffle(20_232, seed=42, reshuffle_each_iteration=False)
train = ratings.take(16_000)
test = ratings.skip(16_000).take(4_232)

# %%
embedding_dimension = 64

client_model = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.StringLookup(
        vocabulary=unique_client_names, mask_token=None),
        tf.keras.layers.Embedding(len(unique_client_names) + 1,
                                  embedding_dimension)
])

item_model = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.StringLookup(
        vocabulary=unique_gig_imgs, mask_token=None),
        tf.keras.layers.Embedding(len(unique_gig_imgs) + 1,
                                  embedding_dimension)
])

rating_model = tf.keras.Sequential([
        tf.keras.layers.Dense(256, activation="relu"),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(1),
])

# %%
class Model(tfrs.Model):
  def __init__(self, rating_weight: float, retrieval_weight: float) -> None:
    super().__init__()
    self.item_model: tf.keras.Model = item_model
    self.client_model: tf.keras.Model = client_model
    self.rating_model: tf.keras.Model = rating_model
    self.rating_task: tf.keras.layers.Layer = rating_task
    self.retrieval_task: tf.keras.layers.Layer = tfrs.tasks.Retrieval(
        metrics=tfrs.metrics.FactorizedTopK(
            candidates=imgs.batch(128).map(self.item_model)
        )
    )
    self.rating_weight = rating_weight
    self.retrieval_weight = retrieval_weight

  def call(self, features: Dict[Text, tf.Tensor]) -> tf.Tensor:
    # We pick out the user features and pass them into the user model.
    client_embeddings = self.client_model(features["client_names"])
    # And pick out the movie features and pass them into the movie model.
    positive_gig_embeddings = self.item_model(features["gig_img_url"])

    return (
        client_embeddings,
        positive_gig_embeddings,
        # We apply the multi-layered rating model to a concatentation of
        # user and movie embeddings.
        self.rating_model(
            tf.concat([client_embeddings, positive_gig_embeddings], axis=1)
        ),
    )

  def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
    ratings = features.pop("gig_rating")
    client_embeddings, positive_gig_embeddings, rating_predictions = self(features)

    rating_loss = self.rating_task(
        labels=ratings,
        predictions=rating_predictions,
    )

    retrieval_loss = self.retrieval_task(client_embeddings, positive_gig_embeddings)
    # The task computes the loss and the metrics.

    return (self.rating_weight * rating_loss
            + self.retrieval_weight * retrieval_loss)

# %%
metrics = tfrs.metrics.FactorizedTopK(
  candidates=imgs.batch(128).map(item_model)
)

task = tfrs.tasks.Retrieval(
  metrics=metrics
)

rating_task = tfrs.tasks.Ranking(
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=[tf.keras.metrics.RootMeanSquaredError()],
    )

# %%
cached_train = train.shuffle(20_232).batch(7808).cache()
cached_test = test.batch(4096).cache()

model = Model(rating_weight=1.0, retrieval_weight=1.0)
model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.1))

model.fit(cached_train, epochs=3)

model.evaluate(cached_test, return_dict=True)
# Out:
# Epoch 1/3
# 3/3 [==============================] - 57s 14s/step - root_mean_squared_error: 0.7269 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 1.2500e-04 - factorized_top_k/top_100_categorical_accuracy: 6.8750e-04 - loss: 36121.0779 - regularization_loss: 0.0000e+00 - total_loss: 36121.0779
# Epoch 2/3
# 3/3 [==============================] - 50s 12s/step - root_mean_squared_error: 0.1757 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0027 - factorized_top_k/top_100_categorical_accuracy: 0.0166 - loss: 34816.8680 - regularization_loss: 0.0000e+00 - total_loss: 34816.8680
# Epoch 3/3
# 3/3 [==============================] - 46s 12s/step - root_mean_squared_error: 0.1917 - factorized_top_k/top_1_categorical_accuracy: 0.0018 - factorized_top_k/top_5_categorical_accuracy: 0.0018 - factorized_top_k/top_10_categorical_accuracy: 0.0021 - factorized_top_k/top_50_categorical_accuracy: 0.0116 - factorized_top_k/top_100_categorical_accuracy: 0.0496 - loss: 28130.3086 - regularization_loss: 0.0000e+00 - total_loss: 28130.3086
# 2/2 [==============================] - 13s 573ms/step - root_mean_squared_error: 0.1717 - factorized_top_k/top_1_categorical_accuracy: 0.0052 - factorized_top_k/top_5_categorical_accuracy: 0.0052 - factorized_top_k/top_10_categorical_accuracy: 0.0066 - factorized_top_k/top_50_categorical_accuracy: 0.0345 - factorized_top_k/top_100_categorical_accuracy: 0.0707 - loss: 11663.8675 - regularization_loss: 0.0000e+00 - total_loss: 11663.8675
# {'root_mean_squared_error': 0.17169147729873657,
#  'factorized_top_k/top_1_categorical_accuracy': 0.005198487546294928,
#  'factorized_top_k/top_5_categorical_accuracy': 0.005198487546294928,
#  'factorized_top_k/top_10_categorical_accuracy': 0.006616257131099701,
#  'factorized_top_k/top_50_categorical_accuracy': 0.03449905663728714,
#  'factorized_top_k/top_100_categorical_accuracy': 0.07065217196941376,
#  'loss': 665.2992553710938,
#  'regularization_loss': 0,
#  'total_loss': 665.2992553710938}

# %%
def predict_gigs(client, top_n=3):
    # Create a model that takes in raw query features, and
    index = tfrs.layers.factorized_top_k.BruteForce(model.client_model)
    # recommends movies out of the entire movies dataset.
    index.index_from_dataset(
      tf.data.Dataset.zip((imgs.batch(100), imgs.batch(100).map(model.item_model)))
    )

    # Get recommendations.
    _, gigs = index(tf.constant([str(client)]))

    print('Top {} recommendations for user {}:\n'.format(top_n, client))
    for i, gig in enumerate(gigs[0, :top_n].numpy()):
        print('{}. {}'.format(i+1, gig.decode("utf-8")))

# %%
predict_gigs('', 20)
# Out:
# Top 20 recommendations for user :
#
# 1. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 2. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 3. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 4. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 5. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 6. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 7. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 8. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 9. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg
# 10. https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/192437271/original/3fb8af5466dc09f13e2afaccf22c6708f0a8976e.jpg

# %%
def predict_rating(client, gig):
    trained_gig_embeddings, trained_client_embeddings, predicted_rating = model({
          "client_names": np.array([str(client)]),
          "gig_img_url": np.array([gig])
      })
    print("Predicted rating for {}: {}".format(gig, predicted_rating.numpy()[0][0]))

# %%
predict_rating('lifehossain', 'https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/9377852/original/7fa1ab489ad31ef89c2f5c7eea6870cadd4fe27d.jpg')
# Out:
# Predicted rating for https://fiverr-res.cloudinary.com/t_gig_cards_web,q_auto,f_auto/gigs/9377852/original/7fa1ab489ad31ef89c2f5c7eea6870cadd4fe27d.jpg: 0.8964329957962036
